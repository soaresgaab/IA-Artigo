# %% [markdown]
# <a href="https://colab.research.google.com/github/soaresgaab/IA-Artigo/blob/main/ArtigoIA(Tratamento_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **--> Caregamento e Understanding do dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

dataset1_path = '/content/drive/MyDrive/IA/dataset_artigo/train.csv'

# %%
df_1 = pd.read_csv(dataset1_path)
df_1
# Out:
#         Unnamed: 0  TransactionID_x  isFraud  TransactionDT  TransactionAmt  \
# 0                0          2987000        0          86400           68.50
# 1                1          2987001        0          86401           29.00
# 2                2          2987002        0          86469           59.00
# 3                3          2987003        0          86499           50.00
# 4                4          2987004        0          86506           50.00
# ...            ...              ...      ...            ...             ...
# 590535      590535          3577535        0       15811047           49.00
# 590536      590536          3577536        0       15811049           39.50
# 590537      590537          3577537        0       15811079           30.95
# 590538      590538          3577538        0       15811088          117.00
# 590539      590539          3577539        0       15811131          279.95
#
# ...

# %%
df_1.head()
# Out:
#    Unnamed: 0  TransactionID_x  isFraud  TransactionDT  TransactionAmt  \
# 0           0          2987000        0          86400            68.5
# 1           1          2987001        0          86401            29.0
# 2           2          2987002        0          86469            59.0
# 3           3          2987003        0          86499            50.0
# 4           4          2987004        0          86506            50.0
#
#    ProductCD  card1  card2  card3  card4  ...  id_31  id_32  id_33  id_34  \
# 0          4  13926  321.0  150.0      1  ...    123   32.0    164      3
# 1          4   2755  404.0  150.0      2  ...     98   32.0     48      2
# 2          4   4663  490.0  150.0      3  ...     44   24.0    132      3
# 3          4  18132  567.0  150.0      2  ...     44   24.0    132      3
# 4          1   4497  514.0  150.0      2  ...     44   24.0     40      3
#
#    id_35  id_36  id_37  id_38  DeviceType  DeviceInfo
# ...

# %%
df_1.isnull().sum()
# Out:
# Unnamed: 0         0
# TransactionID_x    0
# isFraud            0
# TransactionDT      0
# TransactionAmt     0
#                   ..
# id_36              0
# id_37              0
# id_38              0
# DeviceType         0
# DeviceInfo         0
# Length: 436, dtype: int64

# %% [markdown]
# # **--> Seleção dos 19 preditores**

# %%
meus_preditores = ["isFraud", "TransactionAmt", "ProductCD", "DeviceType", "DeviceInfo", "R_emaildomain", "P_emaildomain", "addr1", "addr2",
              "card1", "card2", "card3", "card4", "C1", "C2", "C3", "C4", "C5", "C6"]

# %%
df_1 = df_1[meus_preditores]

# %% [markdown]
# # **--> Remoção de possíveis duplicatas**

# %%
df_1 = df_1[meus_preditores].drop_duplicates()

# %% [markdown]
# # **--> Inserção de técnicas abordadas no artigo**

# %% [markdown]
# Alguns registros
# possuíam dados com valores nao preenchidos e, nesses casos, foi utilizado  imputation [Moepya et al. 2016]. Preditores categoricos foram transformados usando
# CatBoost [Bourdonnaye and Daniel 2021]. Originalmente, os dados sao divididos em subconjuntos para treino e para teste. Entretanto, este trabalho adota uma
# metodologia diferente para separação dos dados, conforme descrito na próxima
# seção. Apenas o subconjunto de treino (cerca de 500 mil registros) foi usado,
# sendo posteriormente dividido em treino e teste nos experimentos. O percentual
# de transações fraudulentas nesse subconjunto é de 3,50%.

# %%
from sklearn.impute import SimpleImputer

col_num = df_1.select_dtypes(include=['number']).columns
col_cat = df_1.select_dtypes(exclude=['number']).columns

# %%
print(col_num)
print(col_cat)
# Out:
# Index(['isFraud', 'TransactionAmt', 'ProductCD', 'DeviceType', 'DeviceInfo',
#        'R_emaildomain', 'P_emaildomain', 'addr1', 'addr2', 'card1', 'card2',
#        'card3', 'card4', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6'],
#       dtype='object')
# Index([], dtype='object')

# %%
imputer_num = SimpleImputer(strategy='median')
df_1[col_num] = imputer_num.fit_transform(df_1[col_num])

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 7.9 MB/s eta 0:00:00
# ...

# %%
from category_encoders.cat_boost import CatBoostEncoder

# %%
col_cat = ["ProductCD", "DeviceType", "DeviceInfo", "P_emaildomain", "R_emaildomain", "card4"]
df_1[col_cat] = df_1[col_cat].astype(str)

# %%
print(df_1["DeviceType"])
# Out:
# 0         1.0
# 1         1.0
# 2         0.0
# 3         0.0
# 4         0.0
#          ...
# 590533    0.0
# 590534    0.0
# 590535    0.0
# 590536    0.0
# 590537    0.0
# Name: DeviceType, Length: 489140, dtype: object

# %% [markdown]
# Obs: Sem necessidade de aplicação do CastBoot, pois não há colunas categóricas.

# %% [markdown]
# # **--> Salvamento do dataset tratado**

# %%
df_1.to_csv('/content/drive/MyDrive/IA/dataset_artigo/dataset_treinado.csv', index=False)
print("Dataset tratado salvo com sucesso!")
# Out:
# Dataset tratado salvo com sucesso!
